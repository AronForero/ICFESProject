# %% [markdown]
# ### Archivos PRESABER del 2014-2 al 2017-1

# %%
import pandas as pd
# %run -i ../tools/functions.py

# %%
PRESABER_2014_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20142-RGSTRO-CLFCCN.txt", delimiter = "|", nrows=20)

# %%
PRESABER_2015_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20151-RGSTRO-CLFCCN.txt", delimiter = "|", nrows=20)

# %%
PRESABER_2015_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20152-RGSTRO-CLFCCN.txt", delimiter = "|", nrows=20)

# %%
PRESABER_2016_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20161-RGSTRO-CLFCCN.txt", delimiter = "|", nrows=20)

# %%
PRESABER_2016_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20162-RGSTRO-CLFCCN.txt", delimiter = "|", nrows=20)

# %% [markdown]
# EL separador usado en el archivo del 2017 es "¬", se cambiara por "|" con la herramienta <i>sed</i> de linux

# %%
# !sed -i 's/¬/|/g' ../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20171-RGSTRO-CLFCCN_2.txt

# %%
PRESABER_2017_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-PRESABER/PRESABER11-20171-RGSTRO-CLFCCN_2.txt", delimiter = "|", nrows=20)

# %% [markdown]
# ### Se crean los Describers

# %%
print("File Shape", PRESABER_2014_2.shape)
print(shape_cols(PRESABER_2014_2))
PRESABER_2014_2.describe()
# Out:
# File Shape (20, 76)
# Columns found:  32
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         4.0                 0.0
# mean   20142.0  15.950000               1.0       100.0                 NaN
# std        0.0   1.099043               0.0         0.0                 NaN
# min    20142.0  15.000000               1.0       100.0                 NaN
# 25%    20142.0  15.000000               1.0       100.0                 NaN
# 50%    20142.0  16.000000               1.0       100.0                 NaN
# 75%    20142.0  16.000000               1.0       100.0                 NaN
# max    20142.0  19.000000               1.0       100.0                 NaN
#
#        ESTU_LIMITA_CONDICIONESPECIAL  ESTU_LIMITA_SDOWN  ESTU_LIMITA_AUTISMO  \
# count                            0.0                0.0                  0.0
# mean                             NaN                NaN                  NaN
# ...

# %%
print("File Shape", PRESABER_2015_1.shape)
print(shape_cols(PRESABER_2015_1))
PRESABER_2015_1.describe()
# Out:
# File Shape (20, 80)
# Columns found:  47
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         1.0                 0.0
# mean   20151.0  16.550000               1.0       100.0                 NaN
# std        0.0   2.038446               0.0         NaN                 NaN
# min    20151.0  15.000000               1.0       100.0                 NaN
# 25%    20151.0  16.000000               1.0       100.0                 NaN
# 50%    20151.0  16.000000               1.0       100.0                 NaN
# 75%    20151.0  16.000000               1.0       100.0                 NaN
# max    20151.0  25.000000               1.0       100.0                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
print("File Shape", PRESABER_2015_2.shape)
print(shape_cols(PRESABER_2015_2))
PRESABER_2015_2.describe()
# Out:
# File Shape (20, 80)
# Columns found:  38
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         0.0                 0.0
# mean   20152.0  15.650000               1.0         NaN                 NaN
# std        0.0   1.182103               0.0         NaN                 NaN
# min    20152.0  13.000000               1.0         NaN                 NaN
# 25%    20152.0  15.000000               1.0         NaN                 NaN
# 50%    20152.0  15.500000               1.0         NaN                 NaN
# 75%    20152.0  16.250000               1.0         NaN                 NaN
# max    20152.0  18.000000               1.0         NaN                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
print("File Shape", PRESABER_2016_1.shape)
print(shape_cols(PRESABER_2016_1))
PRESABER_2016_1.describe()
# Out:
# File Shape (20, 83)
# Columns found:  47
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         1.0                 0.0
# mean   20161.0  16.450000               1.0         1.0                 NaN
# std        0.0   1.099043               0.0         NaN                 NaN
# min    20161.0  14.000000               1.0         1.0                 NaN
# 25%    20161.0  16.000000               1.0         1.0                 NaN
# 50%    20161.0  16.000000               1.0         1.0                 NaN
# 75%    20161.0  17.000000               1.0         1.0                 NaN
# max    20161.0  18.000000               1.0         1.0                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
print("File Shape", PRESABER_2016_2.shape)
print(shape_cols(PRESABER_2016_2))
PRESABER_2016_2.describe()
# Out:
# File Shape (20, 76)
# Columns found:  42
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  \
# count     20.0  20.000000         20.000000         0.0
# mean   20162.0  19.500000         13.000000         NaN
# std        0.0   4.861232         53.665631         NaN
# min    20162.0  14.000000          1.000000         NaN
# 25%    20162.0  17.000000          1.000000         NaN
# 50%    20162.0  18.500000          1.000000         NaN
# 75%    20162.0  20.000000          1.000000         NaN
# max    20162.0  35.000000        241.000000         NaN
#
#        COLE_COD_MCPIO_UBICACION  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# count                       1.0              20.000000              20.000000
# mean                    81001.0              39.350000           39538.350000
# std                         NaN              30.110804           30060.805559
# min                     81001.0               5.000000            5266.000000
# ...

# %%
print("File Shape", PRESABER_2017_1.shape)
print(shape_cols(PRESABER_2017_1))
PRESABER_2017_1.describe()
# Out:
# File Shape (20, 50)
# Columns found:  25
# None
#        PERIODO  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  ESTU_LIMITA_INVIDENTE  \
# count     20.0         0.0                 0.0                    0.0
# mean   20171.0         NaN                 NaN                    NaN
# std        0.0         NaN                 NaN                    NaN
# min    20171.0         NaN                 NaN                    NaN
# 25%    20171.0         NaN                 NaN                    NaN
# 50%    20171.0         NaN                 NaN                    NaN
# 75%    20171.0         NaN                 NaN                    NaN
# max    20171.0         NaN                 NaN                    NaN
#
#        ESTU_LIMITA_CONDICIONESPECIAL  ESTU_LIMITA_SORDO  ESTU_LIMITA_SDOWN  \
# count                            0.0                0.0                0.0
# mean                             NaN                NaN                NaN
# ...
