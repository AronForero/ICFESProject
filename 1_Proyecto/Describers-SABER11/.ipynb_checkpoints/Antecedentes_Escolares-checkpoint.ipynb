# %% [markdown]
# # Exploracion para el Catalogo de Datos
# ### ICFES - SABER11

# %%
import pandas as pd

# %%
# %run -i tools/functions.py

# %% [markdown]
# ## Antecedentes Escolares

# %% [markdown]
#    ### -Antecedentes 2009-2012
# Nota: se estan cargando los archivos con solo 20 rows

# %%
ant2009 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2009-2012/antecedentes2009_2_v1.0.txt", delimiter="|", nrows = 20)
ant2010 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2009-2012/antecedentes2010_2_v1.0.txt", delimiter="|", nrows = 20)
ant2011_1 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2009-2012/antecedentes2011_1_v1.0.txt", delimiter="|", nrows = 20)
ant2011_2 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2009-2012/antecedentes2011_2_v1.0.txt", delimiter="|", nrows = 20)
ant2012_1 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2009-2012/antecedentes2012_1_v1.0.txt", delimiter="|", nrows = 20)
ant2012_2 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2009-2012/antecedentes2012_2_v1.0.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", ant2009.shape)
print(shape_cols(ant2009))
#hay 4 que no son campos numericos (consecutivo, ciudad, universidad, ciudad deseada)
ant2009.describe()
# Out:
# File Shape (20, 41)
# Columns found:  37
# None
#        INAD_ANOSPREESCOLAR  INAD_ANOPRIMERO  INAD_ANOQUINTO  INAD_ANOSEXTO  \
# count            20.000000        20.000000        20.00000      20.000000
# mean              1.300000      1998.350000      2002.65000    2003.500000
# std               1.080935         0.875094         0.48936       0.760886
# min               0.000000      1996.000000      2002.00000    2001.000000
# 25%               0.750000      1998.000000      2002.00000    2003.000000
# 50%               1.000000      1999.000000      2003.00000    2004.000000
# 75%               2.000000      1999.000000      2003.00000    2004.000000
# max               3.000000      1999.000000      2003.00000    2004.000000
#
#        INAD_PERDIOPRIMERO  INAD_PERDIOSEGUNDO  INAD_PERDIOTERCERO  \
# count                20.0                20.0                20.0
# mean                  0.0                 0.0                 0.0
# ...

# %%
print("File Shape", ant2010.shape)
print(shape_cols(ant2010))
ant2010.describe()
# Out:
# File Shape (20, 41)
# Columns found:  37
# None
#        INAD_ANOSPREESCOLAR  INAD_ANOPRIMERO  INAD_ANOQUINTO  INAD_ANOSEXTO  \
# count            20.000000        20.000000       20.000000      20.000000
# mean              1.300000      1997.150000     2001.800000    2003.500000
# std               0.978721         3.759549        3.001754       1.670172
# min               0.000000      1985.000000     1993.000000    1997.000000
# 25%               0.750000      1997.750000     2003.000000    2004.000000
# 50%               1.000000      1999.000000     2003.000000    2004.000000
# 75%               2.000000      1999.000000     2003.000000    2004.000000
# max               3.000000      1999.000000     2003.000000    2004.000000
#
#        INAD_PERDIOPRIMERO  INAD_PERDIOSEGUNDO  INAD_PERDIOTERCERO  \
# count           20.000000           20.000000           20.000000
# mean             0.100000            0.100000            0.050000
# ...

# %%
print("File Shape", ant2011_1.shape)
print(shape_cols(ant2011_1))
ant2011_1.describe()
# Out:
# File Shape (20, 41)
# Columns found:  37
# None
#        INAD_ANOSPREESCOLAR  INAD_ANOPRIMERO  INAD_ANOQUINTO  INAD_ANOSEXTO  \
# count            20.000000        20.000000       20.000000      20.000000
# mean              1.500000      1996.400000     2001.450000    2003.000000
# std               1.100239         5.164657        5.889107       5.656854
# min               0.000000      1985.000000     1985.000000    1985.000000
# 25%               0.750000      1997.000000     2002.000000    2003.000000
# 50%               2.000000      1998.500000     2003.500000    2005.000000
# 75%               2.000000      2000.000000     2005.000000    2006.000000
# max               3.000000      2000.000000     2005.000000    2006.000000
#
#        INAD_PERDIOPRIMERO  INAD_PERDIOSEGUNDO  INAD_PERDIOTERCERO  \
# count                20.0           20.000000                20.0
# mean                  0.0            0.050000                 0.0
# ...

# %%
print("File Shape", ant2011_2.shape)
print(shape_cols(ant2011_2))
ant2011_2.describe()
# Out:
# File Shape (20, 41)
# Columns found:  37
# None
#        INAD_ANOSPREESCOLAR  INAD_ANOPRIMERO  INAD_ANOQUINTO  INAD_ANOSEXTO  \
# count            20.000000        20.000000       20.000000       20.00000
# mean              1.200000      1997.800000     2003.250000     2004.40000
# std               0.951453         4.958777        4.552327        4.71727
# min               0.000000      1985.000000     1985.000000     1985.00000
# 25%               1.000000      1998.250000     2004.000000     2005.00000
# 50%               1.000000      2000.000000     2004.500000     2006.00000
# 75%               1.250000      2001.000000     2005.000000     2006.00000
# max               3.000000      2001.000000     2007.000000     2008.00000
#
#        INAD_PERDIOPRIMERO  INAD_PERDIOSEGUNDO  INAD_PERDIOTERCERO  \
# count           20.000000                20.0           20.000000
# mean             0.100000                 0.0            0.150000
# ...

# %%
print("File Shape", ant2012_1.shape)
print(shape_cols(ant2012_1))
ant2012_1.describe()
# Out:
# File Shape (20, 41)
# Columns found:  37
# None
#        INAD_ANOSPREESCOLAR  INAD_ANOPRIMERO  INAD_ANOQUINTO  INAD_ANOSEXTO  \
# count            20.000000        20.000000       20.000000      20.000000
# mean              1.800000      1996.700000     2001.250000    2002.050000
# std               1.151658         6.173799        7.347574       7.373316
# min               0.000000      1985.000000     1985.000000    1985.000000
# 25%               1.000000      1996.000000     2000.500000    2001.500000
# 50%               2.000000      1999.500000     2005.000000    2006.000000
# 75%               3.000000      2001.000000     2006.000000    2006.250000
# max               3.000000      2002.000000     2007.000000    2008.000000
#
#        INAD_PERDIOPRIMERO  INAD_PERDIOSEGUNDO  INAD_PERDIOTERCERO  \
# count           20.000000           20.000000           20.000000
# mean             0.050000            0.050000            0.100000
# ...

# %%
print("File Shape", ant2012_2.shape)
print(shape_cols(ant2012_2))
ant2012_2.describe()
# Out:
# File Shape (20, 41)
# Columns found:  37
# None
#        INAD_ANOSPREESCOLAR  INAD_ANOPRIMERO  INAD_ANOQUINTO  INAD_ANOSEXTO  \
# count            20.000000        20.000000       20.000000      20.000000
# mean              1.300000      1999.850000     2004.950000    2006.450000
# std               0.732695         2.641272        1.538112       0.759155
# min               0.000000      1992.000000     1999.000000    2005.000000
# 25%               1.000000      2000.000000     2005.000000    2006.000000
# 50%               1.000000      2001.000000     2005.000000    2006.500000
# 75%               1.250000      2001.000000     2006.000000    2007.000000
# max               3.000000      2002.000000     2006.000000    2008.000000
#
#        INAD_PERDIOPRIMERO  INAD_PERDIOSEGUNDO  INAD_PERDIOTERCERO  \
# count           20.000000           20.000000           20.000000
# mean             0.100000            0.100000            0.100000
# ...

# %% [markdown]
# ### -Antecedentes 2014
# nota: muy pocas columnas numericas... revisar

# %%
ant2014_1 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2014/antecedentes_20141_v1-0.txt", delimiter="|", nrows = 20)
ant2014_2 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/antecedentes2014/antecedentes_20142_v1-0.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", ant2014_1.shape)
print(shape_cols(ant2014_1))
ant2014_1.describe()
# Out:
# File Shape (20, 42)
# Columns found:  12
# None
#        FINS_ANOSPREESCOLAR  FINS_ANOQUINTOTERMINOAPROBO  \
# count             20.00000                    20.000000
# mean               2.10000                  2006.200000
# std                0.91191                     1.542384
# min                0.00000                  2001.000000
# 25%                1.75000                  2005.750000
# 50%                2.00000                  2007.000000
# 75%                3.00000                  2007.000000
# max                3.00000                  2007.000000
#
#        FINS_ANOMATRICULAPRIMERO  FINS_ANOMATRICULASEXTO  \
# count                 20.000000               20.000000
# mean                2001.150000             2007.200000
# std                    1.871532                1.542384
# min                 1994.000000             2002.000000
# 25%                 2001.000000             2006.750000
# 50%                 2002.000000             2008.000000
# ...

# %%
print("File Shape", ant2014_2.shape)
print(shape_cols(ant2014_2))
ant2014_2.describe()
# Out:
# File Shape (20, 42)
# Columns found:  11
# None
#        FINS_ANOSPREESCOLAR  FINS_ANOQUINTOTERMINOAPROBO  \
# count             20.00000                    20.000000
# mean               1.60000                  2006.700000
# std                0.88258                     0.978721
# min                0.00000                  2003.000000
# 25%                1.00000                  2007.000000
# 50%                1.00000                  2007.000000
# 75%                2.00000                  2007.000000
# max                3.00000                  2007.000000
#
#        FINS_ANOMATRICULAPRIMERO  FINS_ANOMATRICULASEXTO  \
# count                 20.000000               20.000000
# mean                2001.950000             2007.900000
# std                    0.223607                0.447214
# min                 2001.000000             2006.000000
# 25%                 2002.000000             2008.000000
# 50%                 2002.000000             2008.000000
# ...

# %% [markdown]
# ### -Expectativas 2014

# %%
exp2014_1 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/expectativas2014/expectativas_20141_v1-0.txt", delimiter="|", nrows = 20)
exp2014_2 = pd.read_csv("DatosFTPICFES/SABER11/SB11-ANTECEDENTESESCOLARES/expectativas2014/expectativas_20142_v1-0.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", exp2014_1.shape)
print(shape_cols(exp2014_1))
exp2014_1.describe()
# Out:
# File Shape (20, 8)
# Columns found:  7
# None
#        FINS_INGRESOCARRERAPROXIMOANO  FINS_PUNTAJEESPERADOMATEMATICA  \
# count                       20.00000                       20.000000
# mean                         3.40000                        3.100000
# std                          0.88258                        0.852242
# min                          1.00000                        1.000000
# 25%                          3.00000                        3.000000
# 50%                          4.00000                        3.000000
# 75%                          4.00000                        4.000000
# max                          4.00000                        4.000000
#
#        FINS_PUNTAJEESPERADOLENGUAJE  FINS_PUNTAJEESPERADOINGLES  \
# count                      20.00000                   20.000000
# mean                        3.25000                    3.550000
# std                         0.55012                    0.686333
# ...

# %%
print("File Shape", exp2014_2.shape)
print(shape_cols(exp2014_2))
exp2014_2.describe()
# Out:
# File Shape (20, 8)
# Columns found:  7
# None
#        FINS_INGRESOCARRERAPROXIMOANO  FINS_PUNTAJEESPERADOMATEMATICA  \
# count                      20.000000                       20.000000
# mean                        2.750000                        3.100000
# std                         0.966546                        0.552506
# min                         1.000000                        2.000000
# 25%                         2.000000                        3.000000
# 50%                         3.000000                        3.000000
# 75%                         3.250000                        3.000000
# max                         4.000000                        4.000000
#
#        FINS_PUNTAJEESPERADOLENGUAJE  FINS_PUNTAJEESPERADOINGLES  \
# count                     20.000000                   20.000000
# mean                       3.300000                    2.900000
# std                        0.571241                    0.852242
# ...
