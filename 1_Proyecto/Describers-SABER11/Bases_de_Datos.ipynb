# %% [markdown]
# ## Exploracion de Datos "Base de Datos"
#
# <span style="color:red">
# __**NO EJECUTAR LAS CELDAS QUE INICIAN CON EL CARACTER *"!"***__
# </span>
#
# falta arreglar los datos que quedaron extraños
# Y convertir a tipo numerico los datos que sean posibles para su procesado

# %%
import pandas as pd
# %run -i ../tools/functions.py

# %% [markdown]
# ### -Registros SABER Año 2000
# de todos los archivos se estan cargando solo 20 lineas

# %%
#BD2000_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0.txt", delimiter="|", nrows = 20)
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_tokens (pandas/_libs/parsers.c:14858)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._convert_with_dtype (pandas/_libs/parsers.c:17119)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._string_convert (pandas/_libs/parsers.c:17347)()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers._string_box_utf8 (pandas/_libs/parsers.c:23041)()
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe7 in position 5: invalid continuation byte
#
# During handling of the above exception, another exception occurred:
#
# UnicodeDecodeError                        Traceback (most recent call last)
# ~/Documents/DataScience/Proyecto/tools/functions.py in <module>()
# ...

# %% [markdown]
# Archivos Codificados en ISO-8859, se deben convertir a UTF-8 asi:
# !iconv -f [codificacion actual] -t [codificacion nueva] file.txt > newfile.txt

# %%
#!iconv -f [ISO-8859-1] -t [utf-8] ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0.txt > ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0-utf8.txt

# %%
BD2000_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0-utf8.txt", delimiter="|", nrows = 20)
BD2000_1.head()
# Out:
#    ESTU_CONSECUTIVO  COLE_COD_ICFES                 COLE_NOMBRE_SEDE  \
# 0  SB11200010000203           83048                INSTITUTO STUDIUM
# 1  SB11200010000204            3327             COLEGIO HEBREO UNION
# 2  SB11200010000205           19364         COLEGIO ANGLO COLOMBIANO
# 3  SB11200010000206           19364         COLEGIO ANGLO COLOMBIANO
# 4  SB11200010000207           24281  COLEGIO SAN JORGE DE INGLATERRA
#
#    IND_ANNO_TERMINO_BACHILLERATO COLE_JORNADA  COLE_VALOR_PENSION ESTU_GENERO  \
# 0                           1999            C                   3           F
# 1                           2000            C                   8           F
# 2                           2000            C                   7           M
# 3                           2000            C                   7           M
# 4                           2000            C                   7           F
#
#    ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# ...

# %%
BD2000_1.iloc[2]
# Out:
# ESTU_CONSECUTIVO                         SB11200010000205
# COLE_COD_ICFES                                      19364
# COLE_NOMBRE_SEDE                 COLEGIO ANGLO COLOMBIANO
# IND_ANNO_TERMINO_BACHILLERATO                        2000
# COLE_JORNADA                                            C
# COLE_VALOR_PENSION                                      7
# ESTU_GENERO                                             M
# ESTU_NACIMIENTO_DIA                                    30
# ESTU_NACIMIENTO_MES                                     4
# ESTU_NACIMIENTO_ANNO                                 1982
# ESTU_DEPTO_PRESENTACION                            BOGOTA
# ESTU_MCPIO_PRESENTACION                       BOGOTA D.C.
# ESTU_LIMITA_INVIDENTE                                 NaN
# ESTU_LIMITA_SORDOINTERPRETE                           NaN
# ESTU_LIMITA_SORDONOINTERPRETE                         NaN
# ESTU_LIMITA_MOTRIZ                                    NaN
# ...

# %% [markdown]
# ### Se hace lo mismo con los archivos restantes
# se elimina el archivo anterior

# %%
#!iconv -f [ISO-8859-1] -t [utf-8] ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20002-RGSTRO-CLFCCN-V1-0.txt > ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20002-RGSTRO-CLFCCN-V1-0utf8.txt
#!rm ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20002-RGSTRO-CLFCCN-V1-0.txt

# %%
#!iconv -f [ISO-8859-1] -t [utf-8] ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20011-RGSTRO-CLFCCN-V1-0.txt > ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20011-RGSTRO-CLFCCN-V1-0utf8.txt
#!rm ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20011-RGSTRO-CLFCCN-V1-0.txt

# %%
#!iconv -f [ISO-8859-1] -t [utf-8] ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20012-RGSTRO-CLFCCN-V1-0.txt > ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20012-RGSTRO-CLFCCN-V1-0utf8.txt
#!rm ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20012-RGSTRO-CLFCCN-V1-0.txt

# %% [markdown]
# ## Quedan Caracteres extraños cuando existe algun separador extraño... Arreglar eso

# %%
#BD2017_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20171-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="¬", nrows = 20)
#BD2017_1.head()
# Out:
# ../tools/functions.py:1: ParserWarning: Falling back to the 'python' engine because the separator encoded in utf-8 is > 1 char long, and the 'c' engine does not support such separators; you can avoid this warning by specifying engine='python'.
#   def letters_to_num(obj):

# %% [markdown]
# ### Vemos que aparecen caracteres extraños debido al separador utilizado (¬)
# borramos estos simbolos extraños y cambiamos el separador por "|" asi:
#
# Utilizamos la herramienta de linux "sed"
#
# !sed -i 's/old_character/new_character/g' file.txt
# option -i: in place, save the changes in the same file
# option g: make the action in all of the file, not just in the first occurrence

# %%
#!sed -i 's/Â//g' ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20171-RGSTRO-CLFCCN-V1-0utf8.txt
#!sed -i 's/¬/|/g' ../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20171-RGSTRO-CLFCCN-V1-0utf8.txt

# %%
BD2017_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20171-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2017_1.index
# Out:
# RangeIndex(start=0, stop=20, step=1)

# %% [markdown]
# ### Cargamos los archivos a objetos Pandas y Creamos los Describers
#
# Desde el primer archivo se puede observar que existen mas de 20 columnas que no son numericas
#
# Se evidencian campos de Femenino y Masculino, El estudiante trabaja SI/NO que pueden ser reemplazados por numeros

# %%
print("File Shape", BD2000_1.shape)
print(shape_cols(BD2000_1))
BD2000_1.describe()
# Out:
# File Shape (20, 57)
# Columns found:  35
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                      20.000000           20.000000
# mean     36659.650000                    1999.750000            3.750000
# std      26346.181298                       0.444262            2.881429
# min       3327.000000                    1999.000000            1.000000
# 25%      17872.250000                    1999.750000            1.000000
# 50%      30625.500000                    2000.000000            3.000000
# 75%      50823.000000                    2000.000000            7.000000
# max      86520.000000                    2000.000000            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             18.900000             6.350000           1980.700000
# ...

# %%
BD2000_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20002-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2000_2.shape)
print(shape_cols(BD2000_2))
BD2000_2.describe()
# Out:
# File Shape (20, 58)
# Columns found:  37
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           20.0           20.000000
# mean     36220.500000                         2000.0            5.250000
# std      32443.716723                            0.0            3.075797
# min         18.000000                         2000.0            1.000000
# 25%       1494.250000                         2000.0            1.750000
# 50%      33951.000000                         2000.0            6.500000
# 75%      60326.750000                         2000.0            8.000000
# max      89862.000000                         2000.0            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             16.050000             5.650000           1980.500000
# ...

# %%
BD2001_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20011-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2001_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20012-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2001_1.shape)
print(shape_cols(BD2001_1))
BD2001_1.describe()
# Out:
# File Shape (20, 57)
# Columns found:  36
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           20.0           20.000000
# mean     53549.800000                         2001.0            4.300000
# std      31153.845796                            0.0            3.262224
# min      18929.000000                         2001.0            1.000000
# 25%      18990.000000                         2001.0            1.000000
# 50%      43772.500000                         2001.0            3.000000
# 75%      89094.000000                         2001.0            8.000000
# max      89474.000000                         2001.0            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             16.600000             5.450000           1983.200000
# ...

# %%
print("File Shape", BD2001_2.shape)
print(shape_cols(BD2001_2))
BD2001_2.describe()
# Out:
# File Shape (20, 57)
# Columns found:  36
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count        20.00000                           20.0                 0.0
# mean      34189.20000                         2001.0                 NaN
# std       27961.11242                            0.0                 NaN
# min          59.00000                         2001.0                 NaN
# 25%        1617.50000                         2001.0                 NaN
# 50%       35704.50000                         2001.0                 NaN
# 75%       49074.00000                         2001.0                 NaN
# max       84012.00000                         2001.0                 NaN
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             14.500000             5.600000           1982.850000
# ...

# %%
BD2002_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20021-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2002_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20022-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2002_1.shape)
print(shape_cols(BD2002_1))
BD2002_1.describe()
# Out:
# File Shape (20, 57)
# Columns found:  33
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                       20.00000           19.000000
# mean     15459.750000                     2001.85000            4.789474
# std      15986.335793                        0.48936            3.505217
# min      11775.000000                     2000.00000            1.000000
# 25%      11874.000000                     2002.00000            1.000000
# 50%      11890.000000                     2002.00000            8.000000
# 75%      11890.000000                     2002.00000            8.000000
# max      83378.000000                     2002.00000            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             15.600000             8.100000           1982.800000
# ...

# %%
print("File Shape", BD2002_2.shape)
print(shape_cols(BD2002_2))
BD2002_2.describe()
# Out:
# File Shape (20, 57)
# Columns found:  35
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           20.0           19.000000
# mean     28219.550000                         2002.0            5.631579
# std      28802.297384                            0.0            2.909955
# min      12054.000000                         2002.0            1.000000
# 25%      12211.000000                         2002.0            3.500000
# 50%      12260.000000                         2002.0            8.000000
# 75%      30273.250000                         2002.0            8.000000
# max      99994.000000                         2002.0            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             17.000000             6.250000           1984.850000
# ...

# %%
BD2003_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20031-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2003_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20032-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2003_1.shape)
print(shape_cols(BD2003_1))
BD2003_1.describe()
# Out:
# File Shape (20, 57)
# Columns found:  37
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           20.0           18.000000
# mean     21945.500000                         2003.0            5.333333
# std      11537.410959                            0.0            3.447079
# min      18788.000000                         2003.0            1.000000
# 25%      18788.000000                         2003.0            1.000000
# 50%      18960.000000                         2003.0            8.000000
# 75%      18960.000000                         2003.0            8.000000
# max      69971.000000                         2003.0            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             13.950000             5.850000           1984.900000
# ...

# %%
print("File Shape", BD2003_2.shape)
print(shape_cols(BD2003_2))
BD2003_2.describe()
# Out:
# File Shape (20, 57)
# Columns found:  34
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           19.0           19.000000
# mean     48560.900000                         2003.0            6.263158
# std      37722.899653                            0.0            2.725234
# min         59.000000                         2003.0            1.000000
# 25%       2196.250000                         2003.0            4.000000
# 50%      55202.500000                         2003.0            8.000000
# 75%      77365.250000                         2003.0            8.000000
# max     104430.000000                         2003.0            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             12.050000             5.850000           1985.050000
# ...

# %%
BD2004_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20041-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2004_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20042-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2004_1.shape)
print(shape_cols(BD2004_1))
BD2004_1.describe()
# Out:
# File Shape (20, 58)
# Columns found:  37
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           17.0           17.000000
# mean     47529.600000                         2004.0            3.117647
# std      35332.233343                            0.0            2.735927
# min      18028.000000                         2004.0            1.000000
# 25%      18093.000000                         2004.0            1.000000
# 50%      27449.500000                         2004.0            1.000000
# 75%      71514.750000                         2004.0            5.000000
# max     112268.000000                         2004.0            8.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            19.000000            19.000000             19.000000
# mean             18.105263             5.473684           1986.421053
# ...

# %%
print("File Shape", BD2004_2.shape)
print(shape_cols(BD2004_2))
BD2004_2.describe()
# Out:
# File Shape (20, 40)
# Columns found:  27
# None
#        COLE_COD_ICFES  IND_ANNO_TERMINO_BACHILLERATO  COLE_VALOR_PENSION  \
# count       20.000000                           20.0           20.000000
# mean     99774.100000                         2004.0            0.700000
# std      20937.739754                            0.0            0.470162
# min      68601.000000                         2004.0            0.000000
# 25%      68601.000000                         2004.0            0.000000
# 50%     113134.000000                         2004.0            1.000000
# 75%     113134.000000                         2004.0            1.000000
# max     113134.000000                         2004.0            1.000000
#
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             12.550000             7.300000           1986.900000
# ...

# %%
BD2005_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20051-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2005_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20052-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2005_1.shape)
print(shape_cols(BD2005_1))
BD2005_1.describe()
# Out:
# File Shape (20, 83)
# Columns found:  50
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20051.0            18.400000             7.300000
# std        0.0             8.923063             3.096688
# min    20051.0             2.000000             2.000000
# 25%    20051.0             9.750000             5.000000
# 50%    20051.0            21.000000             7.000000
# 75%    20051.0            26.000000            10.000000
# max    20051.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1987.650000  16.500000                     NaN
# std                1.308877   1.357242                     NaN
# min             1986.000000  12.000000                     NaN
# 25%             1987.000000  16.000000                     NaN
# ...

# %%
print("File Shape", BD2005_2.shape)
print(shape_cols(BD2005_2))
BD2005_2.describe()
# Out:
# File Shape (20, 82)
# Columns found:  49
# None
#        ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  ESTU_NACIMIENTO_ANNO  \
# count            20.000000            20.000000             20.000000
# mean             17.100000             7.550000           1988.700000
# std              10.612307             3.017057              1.525226
# min               2.000000             2.000000           1987.000000
# 25%               7.750000             5.500000           1988.000000
# 50%              17.000000             8.000000           1988.000000
# 75%              27.250000            10.000000           1989.000000
# max              31.000000            12.000000           1994.000000
#
#        ESTU_EDAD  ESTU_LIMITA_BAJAVISION  ESTU_LIMITA_SORDOCEGUERA  \
# count  20.000000                     0.0                       0.0
# mean   15.600000                     NaN                       NaN
# std     1.500877                     NaN                       NaN
# ...

# %%
BD2006_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20061-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2006_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20062-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2006_1.shape)
print(shape_cols(BD2006_1))
BD2006_1.describe()
# Out:
# File Shape (20, 85)
# Columns found:  53
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20061.0            14.350000             6.550000
# std        0.0             9.538151             3.748333
# min    20061.0             2.000000             1.000000
# 25%    20061.0             7.250000             3.000000
# 50%    20061.0            12.500000             7.500000
# 75%    20061.0            24.000000             9.250000
# max    20061.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1988.350000  16.800000                     NaN
# std                1.225819   1.281447                     NaN
# min             1986.000000  15.000000                     NaN
# 25%             1988.000000  16.000000                     NaN
# ...

# %%
print("File Shape", BD2006_2.shape)
print(shape_cols(BD2006_2))
BD2006_2.describe()
# Out:
# File Shape (20, 85)
# Columns found:  53
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20062.0            16.050000             6.450000
# std        0.0             9.264959             3.068945
# min    20062.0             1.000000             1.000000
# 25%    20062.0             7.750000             5.000000
# 50%    20062.0            17.500000             6.500000
# 75%    20062.0            23.500000             9.250000
# max    20062.0            29.000000            11.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1988.750000  16.800000                     NaN
# std                2.769667   2.858045                     NaN
# min             1979.000000  12.000000                     NaN
# 25%             1988.750000  15.750000                     NaN
# ...

# %%
BD2007_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20071-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2007_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20072-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2007_1.shape)
print(shape_cols(BD2007_1))
BD2007_1.describe()
# Out:
# File Shape (20, 84)
# Columns found:  53
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20071.0            16.150000             8.350000
# std        0.0             8.215999             3.437793
# min    20071.0             2.000000             1.000000
# 25%    20071.0            10.750000             5.750000
# 50%    20071.0            16.000000            10.000000
# 75%    20071.0            21.250000            11.000000
# max    20071.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1990.250000  15.850000                     NaN
# std                1.551739   1.531253                     NaN
# min             1987.000000  12.000000                     NaN
# 25%             1990.000000  16.000000                     NaN
# ...

# %%
print("File Shape", BD2007_2.shape)
print(shape_cols(BD2007_2))
BD2007_2.describe()
# Out:
# File Shape (20, 84)
# Columns found:  52
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20072.0            14.100000             7.000000
# std        0.0             9.256008             3.195391
# min    20072.0             1.000000             1.000000
# 25%    20072.0             5.750000             5.750000
# 50%    20072.0            13.500000             8.000000
# 75%    20072.0            21.500000             9.000000
# max    20072.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count              20.00000  20.000000                     0.0
# mean             1990.25000  16.200000                     NaN
# std                 0.71635   0.615587                     NaN
# min              1989.00000  15.000000                     NaN
# 25%              1990.00000  16.000000                     NaN
# ...

# %%
BD2008_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20081-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2008_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20082-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2008_1.shape)
print(shape_cols(BD2008_1))
BD2008_1.describe()
# Out:
# File Shape (20, 83)
# Columns found:  54
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000              20.0000
# mean   20081.0            15.150000               6.1500
# std        0.0            10.434129               3.8563
# min    20081.0             1.000000               1.0000
# 25%    20081.0             6.750000               3.0000
# 50%    20081.0            13.000000               6.0000
# 75%    20081.0            24.000000              10.0000
# max    20081.0            31.000000              12.0000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1990.700000  16.500000                     NaN
# std                0.864505   0.760886                     NaN
# min             1989.000000  15.000000                     NaN
# 25%             1990.000000  16.000000                     NaN
# ...

# %%
print("File Shape", BD2008_2.shape)
print(shape_cols(BD2008_2))
BD2008_2.describe()
# Out:
# File Shape (20, 91)
# Columns found:  59
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20082.0            12.000000             6.100000
# std        0.0             8.967779             3.611386
# min    20082.0             1.000000             1.000000
# 25%    20082.0             3.750000             3.000000
# 50%    20082.0            11.000000             6.000000
# 75%    20082.0            17.000000             9.000000
# max    20082.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1990.300000  17.250000                     NaN
# std                1.454575   1.618154                     NaN
# min             1986.000000  15.000000                     NaN
# 25%             1990.000000  16.000000                     NaN
# ...

# %%
BD2009_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20091-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2009_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20092-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2009_1.shape)
print(shape_cols(BD2009_1))
BD2009_1.describe()
# Out:
# File Shape (20, 97)
# Columns found:  65
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20091.0            15.450000             7.600000
# std        0.0             8.970566             3.408967
# min    20091.0             1.000000             1.000000
# 25%    20091.0             7.500000             5.000000
# 50%    20091.0            15.500000             8.500000
# 75%    20091.0            22.250000            10.250000
# max    20091.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1991.900000  16.200000                     NaN
# std                0.718185   0.615587                     NaN
# min             1990.000000  15.000000                     NaN
# 25%             1992.000000  16.000000                     NaN
# ...

# %%
print("File Shape", BD2009_2.shape)
print(shape_cols(BD2009_2))
BD2009_2.describe()
# Out:
# File Shape (20, 121)
# Columns found:  81
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            19.000000            19.000000
# mean   20092.0            14.421053             7.842105
# std        0.0             7.805381             3.670652
# min    20092.0             2.000000             2.000000
# 25%    20092.0            10.500000             4.500000
# 50%    20092.0            12.000000             9.000000
# 75%    20092.0            21.000000            11.500000
# max    20092.0            29.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             19.000000  20.000000                     0.0
# mean            1990.000000  18.450000                     NaN
# std                4.737557   4.718106                     NaN
# min             1972.000000  16.000000                     NaN
# 25%             1990.000000  16.000000                     NaN
# ...

# %%
BD2010_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20101-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2010_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20102-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2010_1.shape)
print(shape_cols(BD2010_1))
BD2010_1.describe()
# Out:
# File Shape (20, 79)
# Columns found:  49
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20101.0            15.900000             6.250000
# std        0.0             9.233235             3.160197
# min    20101.0             2.000000             1.000000
# 25%    20101.0             5.000000             3.000000
# 50%    20101.0            17.500000             7.000000
# 75%    20101.0            23.250000             8.250000
# max    20101.0            30.000000            11.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000   20.00000                     0.0
# mean            1988.450000   20.70000                     NaN
# std                5.443248    5.40078                     NaN
# min             1970.000000   16.00000                     NaN
# 25%             1986.500000   17.00000                     NaN
# ...

# %%
print("File Shape", BD2010_2.shape)
print(shape_cols(BD2010_2))
BD2010_2.describe()
# Out:
# File Shape (20, 114)
# Columns found:  77
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20102.0            15.450000             7.700000
# std        0.0             9.332879             3.130495
# min    20102.0             1.000000             2.000000
# 25%    20102.0             7.750000             5.750000
# 50%    20102.0            16.500000             8.500000
# 75%    20102.0            23.500000             9.250000
# max    20102.0            29.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1992.350000  17.000000                     NaN
# std                3.328901   3.228166                     NaN
# min             1979.000000  15.000000                     NaN
# 25%             1992.750000  16.000000                     NaN
# ...

# %%
BD2011_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20111-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2011_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20112-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2011_1.shape)
print(shape_cols(BD2011_1))
BD2011_1.describe()
# Out:
# File Shape (20, 114)
# Columns found:  80
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            19.000000            19.000000
# mean   20111.0            15.578947             6.052632
# std        0.0             9.850639             3.978745
# min    20111.0             3.000000             1.000000
# 25%    20111.0             5.000000             1.000000
# 50%    20111.0            16.000000             7.000000
# 75%    20111.0            24.000000             9.000000
# max    20111.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             19.000000  20.000000                     0.0
# mean            1991.789474  18.500000                     NaN
# std                2.760414   2.564946                     NaN
# min             1985.000000  15.000000                     NaN
# 25%             1991.500000  17.000000                     NaN
# ...

# %%
print("File Shape", BD2011_2.shape)
print(shape_cols(BD2011_2))
BD2011_2.describe()
# Out:
# File Shape (20, 114)
# Columns found:  86
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0              20.0000            20.000000
# mean   20112.0              13.3000             6.950000
# std        0.0               8.8799             3.762348
# min    20112.0               2.0000             1.000000
# 25%    20112.0               5.0000             3.000000
# 50%    20112.0              14.5000             8.000000
# 75%    20112.0              21.2500            10.000000
# max    20112.0              27.0000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1994.100000  16.400000                     NaN
# std                2.954034   2.998245                     NaN
# min             1984.000000  10.000000                     NaN
# 25%             1994.000000  15.000000                     NaN
# ...

# %%
BD2012_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20121-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2012_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20122-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2012_1.shape)
print(shape_cols(BD2012_1))
BD2012_1.describe()
# Out:
# File Shape (20, 114)
# Columns found:  86
# None
#        PERIODO  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0            20.000000            20.000000
# mean   20121.0            16.650000             6.250000
# std        0.0             9.777929             3.611021
# min    20121.0             2.000000             1.000000
# 25%    20121.0             7.500000             3.000000
# 50%    20121.0            19.000000             6.500000
# 75%    20121.0            22.750000            10.000000
# max    20121.0            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_EDAD  ESTU_LIMITA_BAJAVISION  \
# count             20.000000  20.000000                     0.0
# mean            1988.450000  22.700000                     NaN
# std                7.728791   7.630272                     NaN
# min             1970.000000  16.000000                     NaN
# 25%             1986.750000  17.750000                     NaN
# ...

# %%
print("File Shape", BD2012_2.shape)
print(shape_cols(BD2012_2))
BD2012_2.describe()
# Out:
# File Shape (20, 114)
# Columns found:  86
# None
#        PERIODO  ESTU_EDAD  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0  20.000000            20.000000            20.000000
# mean   20122.0  18.850000            16.550000             6.200000
# std        0.0   5.402485             9.572301             3.518373
# min    20122.0  15.000000             2.000000             1.000000
# 25%    20122.0  16.000000             9.750000             4.000000
# 50%    20122.0  17.000000            19.000000             6.000000
# 75%    20122.0  18.000000            24.000000             8.250000
# max    20122.0  36.000000            31.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_ETNIA  ESTU_LIMITA_BAJAVISION  \
# count              20.00000         3.0                     0.0
# mean             1992.75000        99.0                     NaN
# std                 5.41805         0.0                     NaN
# ...

# %%
BD2013_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20131-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2013_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20132-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2013_1.shape)
print(shape_cols(BD2013_1))
BD2013_1.describe()
# Out:
# File Shape (20, 113)
# Columns found:  88
# None
#        PERIODO  ESTU_EDAD  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0  20.000000            20.000000            20.000000
# mean   20131.0  18.400000            15.500000             6.150000
# std        0.0   3.830625            10.007892             3.587625
# min    20131.0  16.000000             1.000000             1.000000
# 25%    20131.0  16.000000             6.000000             3.750000
# 50%    20131.0  16.500000            18.000000             6.500000
# 75%    20131.0  19.000000            23.250000             8.250000
# max    20131.0  27.000000            30.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_ETNIA  ESTU_LIMITA_BAJAVISION  \
# count             20.000000         1.0                     0.0
# mean            1993.800000         1.0                     NaN
# std                3.860733         NaN                     NaN
# ...

# %%
print("File Shape", BD2013_2.shape)
print(shape_cols(BD2013_2))
BD2013_2.describe()
# Out:
# File Shape (20, 113)
# Columns found:  85
# None
#        PERIODO  ESTU_EDAD  ESTU_NACIMIENTO_DIA  ESTU_NACIMIENTO_MES  \
# count     20.0  20.000000            19.000000            19.000000
# mean   20132.0  21.750000            16.105263             5.578947
# std        0.0   6.273377             7.370321             3.516877
# min    20132.0  15.000000             3.000000             1.000000
# 25%    20132.0  17.000000            11.500000             2.500000
# 50%    20132.0  19.000000            17.000000             6.000000
# 75%    20132.0  27.250000            21.000000             8.000000
# max    20132.0  35.000000            27.000000            12.000000
#
#        ESTU_NACIMIENTO_ANNO  ESTU_ETNIA  ESTU_LIMITA_BAJAVISION  \
# count             19.000000         1.0                     0.0
# mean            1990.368421        99.0                     NaN
# std                6.352694         NaN                     NaN
# ...

# %%
BD2014_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20141-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)
BD2014_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20142-RGSTRO-CLFCCN-V3-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2014_1.shape)
print(shape_cols(BD2014_1))
BD2014_1.describe()
# Out:
# File Shape (20, 102)
# Columns found:  78
# None
#        PERIODO  ESTU_ETNIA  ESTU_LIMITA_COGNITIVA  ESTU_LIMITA_MOTRIZ  \
# count     20.0    6.000000                    0.0                 0.0
# mean   20141.0   33.666667                    NaN                 NaN
# std        0.0   50.606982                    NaN                 NaN
# min    20141.0    1.000000                    NaN                 NaN
# 25%    20141.0    1.000000                    NaN                 NaN
# 50%    20141.0    1.000000                    NaN                 NaN
# 75%    20141.0   74.500000                    NaN                 NaN
# max    20141.0   99.000000                    NaN                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_COD_RESIDE_MCPIO  ESTU_ZONA_RESIDE  \
# count                    0.0              20.000000          20.00000
# mean                     NaN           55607.600000           4.75000
# std                      NaN           32181.595375           3.12671
# ...

# %%
print("File Shape", BD2014_2.shape)
print(shape_cols(BD2014_2))
BD2014_2.describe()
# Out:
# File Shape (20, 136)
# Columns found:  68
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0   20.000000                 0.0
# mean   20142.0  18.600000               1.0   82.000000                 NaN
# std        0.0   4.172592               0.0   37.165349                 NaN
# min    20142.0  16.000000               1.0    1.000000                 NaN
# 25%    20142.0  17.000000               1.0  100.000000                 NaN
# 50%    20142.0  18.000000               1.0  100.000000                 NaN
# 75%    20142.0  18.250000               1.0  100.000000                 NaN
# max    20142.0  35.000000               1.0  100.000000                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
BD2015_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20151-RGSTRO-CLFCCN-V3-0utf8.txt", delimiter="|", nrows = 20)
BD2015_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20152-RGSTRO-CLFCCN-V3-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2015_1.shape)
print(shape_cols(BD2015_1))
BD2015_1.describe()
# Out:
# File Shape (20, 128)
# Columns found:  88
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0   18.000000                 0.0
# mean   20151.0  27.000000               1.0   89.444444                 NaN
# std        0.0   5.505978               0.0   30.751800                 NaN
# min    20151.0  20.000000               1.0    1.000000                 NaN
# 25%    20151.0  23.750000               1.0  100.000000                 NaN
# 50%    20151.0  25.000000               1.0  100.000000                 NaN
# 75%    20151.0  28.500000               1.0  100.000000                 NaN
# max    20151.0  41.000000               1.0  100.000000                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
print("File Shape", BD2015_2.shape)
print(shape_cols(BD2015_2))
BD2015_2.describe()
# Out:
# File Shape (20, 86)
# Columns found:  45
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         0.0                 0.0
# mean   20152.0  17.100000               1.0         NaN                 NaN
# std        0.0   1.293709               0.0         NaN                 NaN
# min    20152.0  16.000000               1.0         NaN                 NaN
# 25%    20152.0  16.000000               1.0         NaN                 NaN
# 50%    20152.0  17.000000               1.0         NaN                 NaN
# 75%    20152.0  17.250000               1.0         NaN                 NaN
# max    20152.0  20.000000               1.0         NaN                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
BD2016_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20161-RGSTRO-CLFCCN-V1-0.txt", delimiter="|", nrows = 20)
BD2016_1_v3 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20161-RGSTRO-CLFCCN-V3-0utf8.txt", delimiter="|", nrows = 20)
BD2016_2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20162-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2016_1.shape)
print(shape_cols(BD2016_1))
BD2016_1.describe()
# Out:
# File Shape (20, 64)
# Columns found:  42
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  \
# count     20.0  20.000000              20.0         1.0
# mean   20161.0  27.350000               1.0         9.0
# std        0.0   5.833434               0.0         NaN
# min    20161.0  15.000000               1.0         9.0
# 25%    20161.0  24.750000               1.0         9.0
# 50%    20161.0  25.500000               1.0         9.0
# 75%    20161.0  32.250000               1.0         9.0
# max    20161.0  38.000000               1.0         9.0
#
#        ESTU_LIMITA_COGNITIVA  ESTU_LIMITA_MOTRIZ  ESTU_LIMITA_INVIDENTE  \
# count                    0.0                 0.0                    0.0
# mean                     NaN                 NaN                    NaN
# std                      NaN                 NaN                    NaN
# min                      NaN                 NaN                    NaN
# ...

# %%
print("File Shape", BD2016_1_v3.shape)
print(shape_cols(BD2016_1_v3))
BD2016_1_v3.describe()
# Out:
# File Shape (20, 83)
# Columns found:  59
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         1.0                 0.0
# mean   20161.0  27.350000               1.0         9.0                 NaN
# std        0.0   5.833434               0.0         NaN                 NaN
# min    20161.0  15.000000               1.0         9.0                 NaN
# 25%    20161.0  24.750000               1.0         9.0                 NaN
# 50%    20161.0  25.500000               1.0         9.0                 NaN
# 75%    20161.0  32.250000               1.0         9.0                 NaN
# max    20161.0  38.000000               1.0         9.0                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
print("File Shape", BD2016_2.shape)
print(shape_cols(BD2016_2))
BD2016_2.describe()
# Out:
# File Shape (20, 81)
# Columns found:  52
# None
#        PERIODO  ESTU_EDAD  ESTU_PAIS_RESIDE  ESTU_ETNIA  ESTU_LIMITA_MOTRIZ  \
# count     20.0  20.000000              20.0         0.0                 0.0
# mean   20162.0  18.200000               1.0         NaN                 NaN
# std        0.0   3.172248               0.0         NaN                 NaN
# min    20162.0  16.000000               1.0         NaN                 NaN
# 25%    20162.0  16.750000               1.0         NaN                 NaN
# 50%    20162.0  17.000000               1.0         NaN                 NaN
# 75%    20162.0  18.000000               1.0         NaN                 NaN
# max    20162.0  28.000000               1.0         NaN                 NaN
#
#        ESTU_LIMITA_INVIDENTE  ESTU_LIMITA_CONDICIONESPECIAL  \
# count                    0.0                            0.0
# mean                     NaN                            NaN
# ...

# %%
BD2017_1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20171-RGSTRO-CLFCCN-V1-0utf8.txt", delimiter="|", nrows = 20)

# %%
print("File Shape", BD2017_1.shape)
print(shape_cols(BD2017_1))
BD2017_1.describe()
# Out:
# File Shape (20, 80)
# Columns found:  31
# None
#        PERIODO  ESTU_ETNIA  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# count     20.0         0.0              20.000000              20.000000
# mean   20171.0         NaN              55.250000           55268.400000
# std        0.0         NaN              29.224854           29205.938921
# min    20171.0         NaN              11.000000           11001.000000
# 25%    20171.0         NaN              23.500000           23631.500000
# 50%    20171.0         NaN              76.000000           76001.000000
# 75%    20171.0         NaN              76.000000           76001.000000
# max    20171.0         NaN              76.000000           76001.000000
#
#        FAMI_CUARTOSHOGAR  COLE_COD_DANE_ESTABLECIMIENTO  COLE_CODIGO_ICFES  \
# count          17.000000                   2.000000e+01          20.000000
# mean            3.176471                   3.753971e+11       84555.050000
# ...
