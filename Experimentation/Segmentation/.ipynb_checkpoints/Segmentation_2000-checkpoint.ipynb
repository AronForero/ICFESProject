# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
# %run -i ../../tools/label_encoder.py
# %run -i ../../tools/functions.py

# %% [markdown]
# # 2000_1

# %%
data_2000_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2000_1.csv', delimiter=';')
data_2000_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2000_2.csv', delimiter=';')

data_2001_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2001_1.csv', delimiter=';')
data_2001_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2001_2.csv', delimiter=';')

data_2002_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2002_1.csv', delimiter=';')
data_2002_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2002_2.csv', delimiter=';')

data_2003_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2003_1.csv', delimiter=';')
data_2003_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2003_2.csv', delimiter=';')

data_2004_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2004_1.csv', delimiter=';')
data_2004_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2004_2.csv', delimiter=';')

data_2005_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2005_1.csv', delimiter=';')
data_2005_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2005_2.csv', delimiter=';')

data_2006_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2006_1.csv', delimiter=';')
data_2006_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2006_2.csv', delimiter=';')

data_2007_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2007_1.csv', delimiter=';')
data_2007_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2007_2.csv', delimiter=';')

data_2008_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2008_1.csv', delimiter=';')
data_2008_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2008_2.csv', delimiter=';')

data_2009_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2009_1.csv', delimiter=';')
data_2009_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2009_2.csv', delimiter=';')

data_2010_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2010_1.csv', delimiter=';')
data_2010_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2010_2.csv', delimiter=';')

data_2011_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2011_1.csv', delimiter=';')
data_2011_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2011_2.csv', delimiter=';')

data_2012_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2012_1.csv', delimiter=';')
data_2012_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2012_2.csv', delimiter=';')

data_2013_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2013_1.csv', delimiter=';')
data_2013_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2013_2.csv', delimiter=';')

data_2014_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2014_1.csv', delimiter=';')
data_2014_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2014_2.csv', delimiter=';')

data_2015_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2015_1.csv', delimiter=';')
data_2015_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2015_2.csv', delimiter=';')

data_2016_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2016_1.csv', delimiter=';')
data_2016_1_V2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2016_1_V2.csv', delimiter=';')
data_2016_2 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2016_2.csv', delimiter=';')

data_2017_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/READY/2017_1.csv', delimiter=';')

# %%
O_data_2000_1 = pd.read_csv('../../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0.txt', delimiter='|', 
                            encoding='iso-8859-1')
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,12,14,15,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
data_2000_1.columns
# Out:
# Index(['COLE_COD_ICFES', 'IND_ANNO_TERMINO_BACHILLERATO', 'COLE_JORNADA',
#        'COLE_VALOR_PENSION', 'ESTU_GENERO', 'ESTU_NACIMIENTO_DIA',
#        'ESTU_NACIMIENTO_MES', 'ESTU_NACIMIENTO_ANNO', 'ESTU_LIMITA_INVIDENTE',
#        'ESTU_LIMITA_SORDONOINTERPRETE', 'ESTU_LIMITA_MOTRIZ', 'PUNT_BIOLOGIA',
#        'PUNT_MATEMATICAS', 'PUNT_FILOSOFIA', 'PUNT_FISICA', 'PUNT_HISTORIA',
#        'PUNT_QUIMICA', 'PUNT_LENGUAJE', 'PUNT_GEOGRAFIA',
#        'COD_INTERDISCIPLINAR', 'PUNT_INTERDISCIPLINAR', 'COD_IDIOMA',
#        'PUNT_IDIOMA', 'ESTU_IES_COD_DESEADA', 'ESTU_RAZONINSTITUTO',
#        'ESTU_CARRDESEADA_COD', 'ESTU_CARRDESEADA_RAZON', 'FAMI_PERSONAS_HOGAR',
#        'FAMI_VIVIENDA_PROPIA', 'FAMI_DEUDA_VIVIENDA', 'FAMI_APORTANTES',
#        'FAMI_INGRESO_FMILIAR_MENSUAL', 'FAMI_LEE_ESCRIBE_PADRE',
#        'FAMI_LEE_ESCRIBE_MADRE', 'FAMI_EDUCA_PADRE', 'FAMI_EDUCA_MADRE',
#        'FAMI_OCUPA_PADRE', 'FAMI_OCUPA_MADRE', 'FAMI_NUM_HERMANOS',
# ...

# %% [markdown]
# In first place i will group the data for **ESTU_RESIDE_DEPTO**

# %%
data_2000_1['ESTU_RESIDE_DEPTO'].value_counts()
# Out:
# 27    39146
# 19    11608
# 9      8325
# 3      6850
# 0      3788
# 2      1102
# 13      806
# 23      548
# 22      540
# 24      528
# 15      498
# 26      441
# 18      391
# 20      387
# 12      331
# 4       320
# 6       312
# 7       260
# 5       249
# 16      192
# 10      182
# 17      175
# 8       130
# 21      126
# 1       108
# 25       80
# 11       57
# 14       28
# Name: ESTU_RESIDE_DEPTO, dtype: int64

# %%
O_data_2000_1['ESTU_RESIDE_DEPTO'].value_counts()
# Out:
# VALLE              39224
# NARIO             11616
# CAUCA               8332
# BOGOTA              6857
# ANTIOQUIA           3794
# ATLANTICO           1103
# CUNDINAMARCA         808
# RISARALDA            548
# QUINDIO              541
# SANTANDER            530
# HUILA                498
# TOLIMA               443
# META                 391
# NORTE SANTANDER      387
# CORDOBA              332
# BOLIVAR              321
# CALDAS               312
# CAQUETA              261
# BOYACA               249
# LA GUAJIRA           192
# CESAR                182
# MAGDALENA            175
# CASANARE             131
# PUTUMAYO             126
# ARAUCA               108
# SUCRE                 80
# CHOCO                 57
# GUAVIARE              28
# Name: ESTU_RESIDE_DEPTO, dtype: int64

# %%
Geo_Nombre = pd.DataFrame(O_data_2000_1['ESTU_RESIDE_DEPTO'].value_counts()).sort_values(by='ESTU_RESIDE_DEPTO')

# %%
Geo_Cod = pd.DataFrame(data_2000_1['ESTU_RESIDE_DEPTO'].value_counts()).sort_values(by='ESTU_RESIDE_DEPTO')

# %%
prueba = pd.DataFrame({'col1':Geo_Cod.index, 'col2': Geo_Nombre.index})

# %%
prueba
# Out:
#     col1             col2
# 0     14         GUAVIARE
# 1     11            CHOCO
# 2     25            SUCRE
# 3      1           ARAUCA
# 4     21         PUTUMAYO
# 5      8         CASANARE
# 6     17        MAGDALENA
# 7     10            CESAR
# 8     16       LA GUAJIRA
# 9      5           BOYACA
# 10     7          CAQUETA
# 11     6           CALDAS
# 12     4          BOLIVAR
# 13    12          CORDOBA
# 14    20  NORTE SANTANDER
# 15    18             META
# 16    26           TOLIMA
# 17    15            HUILA
# 18    24        SANTANDER
# 19    22          QUINDIO
# 20    23        RISARALDA
# 21    13     CUNDINAMARCA
# 22     2        ATLANTICO
# 23     0        ANTIOQUIA
# 24     3           BOGOTA
# 25     9            CAUCA
# 26    19           NARIO
# 27    27            VALLE

# %% [markdown]
# New function made, to make the work easier.
#
# Returns the relation

# %%
def get_relation(df1, df2, c):
    Geo_N = pd.DataFrame(df1[c].value_counts()).sort_values(by=c)
    Geo_C = pd.DataFrame(df2[c].value_counts()).sort_values(by=c)
    relation = pd.DataFrame({'col1':Geo_C.index, 'col2': Geo_N.index})
    return(relation)

# %%
Geo_relation_2000_1 = get_relation(O_data_2000_1, data_2000_1, 'ESTU_RESIDE_DEPTO')

# %%
Geo_relation_2000_1
# Out:
#     col1             col2
# 0     14         GUAVIARE
# 1     11            CHOCO
# 2     25            SUCRE
# 3      1           ARAUCA
# 4     21         PUTUMAYO
# 5      8         CASANARE
# 6     17        MAGDALENA
# 7     10            CESAR
# 8     16       LA GUAJIRA
# 9      5           BOYACA
# 10     7          CAQUETA
# 11     6           CALDAS
# 12     4          BOLIVAR
# 13    12          CORDOBA
# 14    20  NORTE SANTANDER
# 15    18             META
# 16    26           TOLIMA
# 17    15            HUILA
# 18    24        SANTANDER
# 19    22          QUINDIO
# 20    23        RISARALDA
# 21    13     CUNDINAMARCA
# 22     2        ATLANTICO
# 23     0        ANTIOQUIA
# 24     3           BOGOTA
# 25     9            CAUCA
# 26    19           NARIO
# 27    27            VALLE

# %%
Geo_Groups_2000_1 = data_2000_1.groupby('ESTU_RESIDE_DEPTO')

# %% [markdown]
# Plotting the targets, the trend did not change, and the average is in the same range or so close.

# %%
fig, axes = plt.subplots(7, 4, sharex=False, figsize=(13, 17))
axs = [i for i in axes.flatten()]
for n, i in enumerate(Geo_Groups.groups.keys()):
    dic = Geo_Groups.get_group(i)
    ax = axs[n]
    ax.plot(dic['PUNT_MATEMATICAS'].sort_values().values)
    idx = Geo_relation_2000_1[Geo_relation_2000_1['col1']==i].index
    ax.set_title('PUNT_MATEMATICAS en '+'\n'+str(Geo_relation_2000_1.loc[idx, 'col2'])+'.')
    ax.grid()
plt.tight_layout(h_pad=2)

# %% [markdown]
# ______

# %% [markdown]
# Buscando Columnas por las cuales dividir

# %%
Geo_Groups_2000_2 = data_2000_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2001_1 = data_2001_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2001_2 = data_2001_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2002_1 = data_2002_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2002_2 = data_2002_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2003_1 = data_2003_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2003_2 = data_2003_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2004_1 = data_2004_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2004_2 = data_2004_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2005_1 = data_2005_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2005_2 = data_2005_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2006_1 = data_2006_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2006_2 = data_2006_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2007_1 = data_2007_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2007_2 = data_2007_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2008_1 = data_2008_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2008_2 = data_2008_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2009_1 = data_2009_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2009_2 = data_2009_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2010_1 = data_2010_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2010_2 = data_2010_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2011_1 = data_2011_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2011_2 = data_2011_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2012_1 = data_2012_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2012_2 = data_2012_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2013_1 = data_2013_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2013_2 = data_2013_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2014_1 = data_2014_1.groupby('ESTU_RESIDE_DEPTO')

##################

Geo_Groups_2014_2 = data_2014_2.groupby('ESTU_COD_RESIDE_DEPTO')

Geo_Groups_2015_1 = data_2015_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2015_2 = data_2015_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2016_1 = data_2016_1.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2016_1_v2 = data_2016_1_v2.groupby('ESTU_RESIDE_DEPTO')
Geo_Groups_2016_2 = data_2016_2.groupby('ESTU_RESIDE_DEPTO')

Geo_Groups_2017_1 = data_2017_1.groupby('ESTU_DEPTO_RESIDE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /home/Foreroo/Proyecto/New_Project/tools/functions.py in <module>()
#       1 Geo_Groups_2000_2 = data_2000_2.groupby('ESTU_RESIDE_DEPTO')
#       2 Geo_Groups_2001_1 = data_2001_1.groupby('ESTU_RESIDE_DEPTO')
# ----> 3 Geo_Groups_200_ = data_200_.groupby('ESTU_RESIDE_DEPTO')
#       4
#       5 Geo_Groups_200_ = data_200_.groupby('ESTU_RESIDE_DEPTO')
#
# NameError: name 'data_200_' is not defined

# %% [markdown]
# ______

# %% [markdown]
# ______

# %%
Grouped = data_2000_1.groupby(['COLE_DEPTO_UBICACION'])[y_list].agg('mean')

# %%
Grouped.head()
# Out:
#                       PUNT_BIOLOGIA  PUNT_MATEMATICAS  PUNT_FILOSOFIA  \
# COLE_DEPTO_UBICACION
# ANTIOQUIA                 43.004464         43.543855       43.634454
# ARAUCA                    41.836364         43.100000       42.672727
# ATLANTICO                 44.272313         44.291439       43.743169
# BOGOTA                    47.302937         46.890691       46.637878
# BOLIVAR                   46.000000         45.655385       45.203077
#
#                       PUNT_FISICA  PUNT_HISTORIA  PUNT_QUIMICA  PUNT_LENGUAJE  \
# COLE_DEPTO_UBICACION
# ANTIOQUIA               43.851103      43.123950     41.920168      43.184086
# ARAUCA                  42.545455      41.800000     41.481818      41.700000
# ATLANTICO               44.748634      43.715847     44.574681      43.660291
# BOGOTA                  46.574163      47.157679     46.790297      46.540845
# BOLIVAR                 47.636923      45.846154     47.978462      44.618462
#
# ...

# %%
fig, axes = plt.subplots(4, 3, sharex=False, figsize=(15, 17))
axs = [i for i in axes.flatten()]
for n, i in enumerate(Grouped.columns):
    dic = Grouped[i]
    ax = axs[n]
    ax.bar(range(len(dic.index)), dic.values, alpha=0.5)
    ax.set_title('PUNTAJE en: '+str(i)+'.')
    ax.set_xticks(range(len(dic.index)))
    ax.set_xticklabels(dic.index, rotation=90)
    ax.grid()
plt.tight_layout(h_pad=2)

# %% [markdown]
# ______

# %% [markdown]
# ______

# %% [markdown]
# ______

# %% [markdown]
# Segmentacion socioeconomica

# %%
SE_Groups_2000_1 = data_2000_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2000_2 = data_2000_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2001_1 = data_2001_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2001_2 = data_2001_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2002_1 = data_2002_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2002_2 = data_2002_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2003_1 = data_2003_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2003_2 = data_2003_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2004_1 = data_2004_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
#SE_Groups_2004_2 = data_2004_2.groupby('') # NO SE PUEDE

#SE_Groups_2005_1 = data_2005_1.groupby('') #No hay datos de la familia
SE_Groups_2005_2 = data_2005_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2006_1 = data_2006_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2006_2 = data_2006_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2007_1 = data_2007_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2007_2 = data_2007_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2008_1 = data_2008_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2008_2 = data_2008_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2009_1 = data_2009_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2009_2 = data_2009_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2010_1 = data_2010_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2010_2 = data_2010_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2011_1 = data_2011_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2011_2 = data_2011_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2012_1 = data_2012_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2012_2 = data_2012_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2013_1 = data_2013_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2013_2 = data_2013_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2014_1 = data_2014_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

###############

SE_Groups_2014_2 = data_2014_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2015_1 = data_2015_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2015_2 = data_2015_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

SE_Groups_2016_1 = data_2016_1.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2016_1_V2 = data_2016_1_V2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')
SE_Groups_2016_2 = data_2016_2.groupby('FAMI_INGRESO_FMILIAR_MENSUAL')

#SE_Groups_2017_1 = data_2017_1.groupby('') #NO SE PUEDE

# %%
print('FAMI_INGRESO_FMILIAR_MENSUAL' in data_2016_1.columns)
print('FAMI_INGRESO_FMILIAR_MENSUAL' in data_2016_2.columns)
# Out:
# True
# True

# %%
'FAMI_INGRESO_FMILIAR_MENSUAL' in data_2017_1.columns
# Out:
# False
