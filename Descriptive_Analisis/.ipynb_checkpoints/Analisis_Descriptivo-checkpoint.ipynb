# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# %run -i ../tools/functions.py
# %matplotlib inline

# %%
file1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0.txt", delimiter="|", encoding="iso-8859-1")
# Out:
# /usr/local/anaconda3/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (5,12,14,15,29,31) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
file1.shape

# %%
file1.iloc[1]
# Out:
# ESTU_CONSECUTIVO                     SB11200010000204
# COLE_COD_ICFES                                   3327
# COLE_NOMBRE_SEDE                 COLEGIO HEBREO UNION
# IND_ANNO_TERMINO_BACHILLERATO                    2000
# COLE_JORNADA                                        C
# COLE_VALOR_PENSION                                  8
# ESTU_GENERO                                         F
# ESTU_NACIMIENTO_DIA                                28
# ESTU_NACIMIENTO_MES                                 4
# ESTU_NACIMIENTO_ANNO                             1982
# ESTU_DEPTO_PRESENTACION                     ATLANTICO
# ESTU_MCPIO_PRESENTACION                  BARRANQUILLA
# ESTU_LIMITA_INVIDENTE                             NaN
# ESTU_LIMITA_SORDOINTERPRETE                       NaN
# ESTU_LIMITA_SORDONOINTERPRETE                     NaN
# ESTU_LIMITA_MOTRIZ                                NaN
# PUNT_BIOLOGIA                                      51
# ...

# %%
df = file1[['COLE_JORNADA', 'PUNT_MATEMATICAS']]

# %%
df.head()
# Out:
#   COLE_JORNADA  PUNT_MATEMATICAS
# 0            C                47
# 1            C                52
# 2            C                58
# 3            C                54
# 4            C                63

# %%
df.boxplot(by='COLE_JORNADA', figsize=(12,10))

# %% [markdown]
# Con matplotlib fue un desastre

# %%
#plt.style.use('ggplot')
plt.plot()
x = df.iloc[:,0].values
y = df.iloc[:,1].values
z = [range(5)]
plt.boxplot((z,y))
plt.title('Boxplot de prueba')
plt.xlabel('Valores')
plt.ylabel('Meses')
plt.show()

# %% [markdown]
# Ahora intento con Seaborn
#     -Salio muy bien, pero detuve el scatter porque se tardaba mucho

# %%
f, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(x="COLE_JORNADA", y="PUNT_MATEMATICAS", data=df, palette="vlag")
sns.swarmplot(x="COLE_JORNADA", y="PUNT_MATEMATICAS", data=df)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /home/Foreroo/Proyecto/tools/functions.py in <module>()
#       1 f, ax = plt.subplots(figsize=(12, 10))
#       2 sns.boxplot(x="COLE_JORNADA", y="PUNT_MATEMATICAS", data=df, palette="vlag")
# ----> 3 sns.swarmplot(x="COLE_JORNADA", y="PUNT_MATEMATICAS", data=df)
#
# /home/Foreroo/.ipython/seaborn/categorical.py in swarmplot(x, y, hue, data, order, hue_order, dodge, orient, color, palette, size, edgecolor, linewidth, ax, **kwargs)
#    2798                        linewidth=linewidth))
#    2799
# -> 2800     plotter.plot(ax, kwargs)
#    2801     return ax
#    2802
#
# /home/Foreroo/.ipython/seaborn/categorical.py in plot(self, ax, kws)
#    1433     def plot(self, ax, kws):
#    1434         """Make the full plot."""
# -> 1435         self.draw_swarmplot(ax, kws)
#    1436         self.add_legend_data(ax)
# ...

# %%
#sns.set(style="ticks")

f, ax = plt.subplots(figsize=(12, 10))
sns.boxplot(x="COLE_JORNADA", y="PUNT_MATEMATICAS", data=df, palette="vlag")
#sns.swarmplot(x="COLE_JORNADA", y="PUNT_MATEMATICAS", data=df)
ax.xaxis.grid(True)
ax.yaxis.grid(True)
ax.set(ylabel="Puntaje")
#sns.despine(trim=True, left=True)

# %% [markdown]
# ### Ejemplo cada año

# %%
file2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20011-RGSTRO-CLFCCN-V1-0.zip", delimiter="|", encoding="iso-8859-1")
file1 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20001-RGSTRO-CLFCCN-V1-0.txt", delimiter="|", encoding="iso-8859-1")
# Out:
# ---------------------------------------------------------------------------
# CParserError                              Traceback (most recent call last)
# /home/Foreroo/Proyecto/tools/functions.py in <module>()
# ----> 1 file2 = pd.read_csv("../DatosFTPICFES/SABER11/SB11-BASES_DE_DATOS/SB11-20011-RGSTRO-CLFCCN-V1-0.zip", delimiter="|", encoding="iso-8859-1")
#
# ...
